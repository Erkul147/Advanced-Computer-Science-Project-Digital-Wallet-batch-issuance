# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import math 
import random

# %%
file_name = 'timeExecutionForHashListGeneration.csv'
hashlist_df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['type', 'amountOfAttributes', 'executionTime'])
hashlist_df
# Out:
#           type  amountOfAttributes  executionTime
# 0     hashlist                   1             24
# 1     hashlist                   2              0
# 2     hashlist                   3              1
# 3     hashlist                   4              0
# 4     hashlist                   5              0
# ...        ...                 ...            ...
# 9994  hashlist                9995            102
# 9995  hashlist                9996            104
# 9996  hashlist                9997            104
# 9997  hashlist                9998            106
# 9998  hashlist                9999            105
#
# [9999 rows x 3 columns]

# %%
file_name = 'timeExecutionForMerkleTreeGeneration.csv'
merkle_tree_df = pd.read_csv(file_name, header = 0, delimiter=",", decimal=".", names=['type', 'amountOfAttributes', 'executionTime'])
merkle_tree_df
# Out:
#             type  amountOfAttributes  executionTime
# 0     merkletree                   1             29
# 1     merkletree                   2              0
# 2     merkletree                   3              0
# 3     merkletree                   4              1
# 4     merkletree                   5              0
# ...          ...                 ...            ...
# 9994  merkletree                9995              4
# 9995  merkletree                9996              4
# 9996  merkletree                9997              4
# 9997  merkletree                9998              4
# 9998  merkletree                9999              4
#
# [9999 rows x 3 columns]

# %%
sns.scatterplot(data=hashlist_df, x='amountOfAttributes', y='executionTime')
plt.xlabel("Amount of Attributes")
plt.ylabel("Execution Time (ms)")
plt.title("Execution Time vs. Attributes: Hashlist")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=merkle_tree_df, x='amountOfAttributes', y='executionTime')
plt.xlabel("Amount of Attributes")
plt.ylabel("Execution Time (ms)")
plt.title("Execution Time vs. Attributes: MerkleTree")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
hashlist_df['bin'] = pd.cut(hashlist_df['amountOfAttributes'], bins=20)
means = hashlist_df.groupby('bin')['executionTime'].mean()
bin_centers = [b.mid for b in means.index]
plt.plot(bin_centers, means.values, color='green', linewidth=2)
# Out:
# C:\Users\Moosdorf\AppData\Local\Temp\ipykernel_11448\3765723069.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   means = hashlist_df.groupby('bin')['executionTime'].mean()

# %%
merkle_tree_df['bin'] = pd.cut(merkle_tree_df['amountOfAttributes'], bins=20)
means = merkle_tree_df.groupby('bin')['executionTime'].mean()
bin_centers = [b.mid for b in means.index]
plt.plot(bin_centers, means.values, color='red', linewidth=2)
# Out:
# C:\Users\Moosdorf\AppData\Local\Temp\ipykernel_11448\2023077030.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   means = merkle_tree_df.groupby('bin')['executionTime'].mean()
